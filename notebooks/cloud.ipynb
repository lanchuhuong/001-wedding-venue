# %%
import sys

sys.path.append("..")

from function.cloud import list_files

venue = "The Thursday Club"


def is_processed(venue):
    return (
        len(
            list_files(filter=rf"processed/adobe_extracted/{venue}/structuredData.json")
        )
        > 0
    )


is_processed(venue)
# Out:
# True

# %%
all_jsons = list_files(filter=r"processed/adobe_extracted/.*/structuredData.json")

# %%
import re

pattern = re.compile(r"processed/adobe_extracted/(.*)/structuredData.json")

all_processed_venues = set([pattern.findall(json)[0] for json in all_jsons])

# %%
from function.retriever import get_all_venue_names_on_cloud

all_venues = get_all_venue_names_on_cloud()

# is_present = [is_processed(venue) for venue in all_venues()]

# %%
all_processed_venues - set(all_venues)
# Out:
# set()

# %%
import io
import os
import re
import sys
import time
from pathlib import Path
from tempfile import NamedTemporaryFile
from typing import Dict, List
from zipfile import ZipFile

import pandas as pd
from dotenv import load_dotenv
from google.cloud import storage
from google.cloud.storage import Client, transfer_manager

sys.path.append("..")
from function.pdf_loader import *

load_dotenv()

# %%
def list_files(bucket_name, filter=None):
    if filter is not None:
        filter = re.compile(filter, re.IGNORECASE)

    client = storage.Client()
    bucket = client.bucket(bucket_name)
    blobs = bucket.list_blobs()
    return [blob.name for blob in blobs if filter is None or filter.search(blob.name)]


def download_file(bucket_name: str, source_blob_name: str, destination_file_name: str):
    os.makedirs(os.path.dirname(destination_file_name), exist_ok=True)

    client = storage.Client()
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(source_blob_name)

    blob.download_to_filename(destination_file_name)
    return destination_file_name


def download_files(bucket_name: str, files: list[str]):
    client = Client()
    bucket = client.bucket(bucket_name)

    # Create download objects
    downloads = [(bucket.blob(file_name), file_name) for file_name in files]

    # Make sure directories exist
    for _, dest_path in downloads:
        os.makedirs(os.path.dirname(dest_path), exist_ok=True)

    # Use transfer_manager to download files in parallel
    results = transfer_manager.download_many(
        downloads,
        max_workers=10,  # adjust number of workers as needed
    )

    return results


def get_storage_client() -> storage.Client:
    """Initialize and return Google Cloud Storage client"""
    return storage.Client()


def upload_file(source_file_path: str, destination_blob_name: str | None = None) -> str:
    """
    Upload a single file to Google Cloud Storage.

    Parameters
    ----------
    source_file_path : str
        Local path to the file to upload
    destination_blob_name : str, optional
        Destination path in the bucket. If None, uses the source filename

    Returns
    -------
    str
        The public URL of the uploaded file
    """
    if destination_blob_name is None:
        destination_blob_name = Path(source_file_path).name

    client = storage.Client()
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(destination_blob_name)

    blob.upload_from_filename(source_file_path)

    return blob.public_url


def upload_files(file_pairs: list[tuple[str, str]]) -> list[str]:
    """
    Upload multiple files to Google Cloud Storage in parallel.

    Parameters
    ----------
    file_pairs : list[tuple[str, str]]
        List of (source_path, destination_path) tuples

    Returns
    -------
    list[str]
        List of public URLs for the uploaded files
    """
    client = Client()
    bucket = client.bucket(bucket_name)

    # Create list of (source_file, destination_blob) tuples
    uploads = [
        (file_path, bucket.blob(dest_path)) for file_path, dest_path in file_pairs
    ]

    # Upload files in parallel
    results = transfer_manager.upload_many(
        uploads,
        max_workers=10,
    )

    # Return public URLs of uploaded files
    return [blob.public_url for _, blob in uploads]


def upload_directory(local_directory: str, bucket_prefix: str = "") -> list[str]:
    """
    Upload an entire directory and its contents recursively.

    Parameters
    ----------
    local_directory : str
        Path to local directory to upload
    bucket_prefix : str, optional
        Prefix to add to all files in the bucket

    Returns
    -------
    list[str]
        List of public URLs for all uploaded files
    """
    local_dir = Path(local_directory)

    # Get all files in directory and subdirectories
    all_files = [
        (str(path), os.path.join(bucket_prefix, path.relative_to(local_dir).as_posix()))
        for path in local_dir.rglob("*")
        if path.is_file()
    ]

    return upload_files(all_files)

# %%
def process_pdf_from_cloud_with_temp_file(
    bucket_name: str,
    blob_name: str,
    output_folder: str,
    client_id: str,
    client_secret: str,
    max_retries: int = 3,
    retry_delay: int = 5,
):
    client = storage.Client()
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(blob_name)

    # Get PDF name and create subfolder
    pdf_name = os.path.splitext(os.path.basename(blob_name))[0]
    output_pdf_dir = os.path.join(output_folder, pdf_name)  # Organized by PDF name
    os.makedirs(output_pdf_dir, exist_ok=True)

    output_zip_path = os.path.join(output_pdf_dir, "sdk.zip")  # ZIP inside subfolder
    temp_file_path = None
    success = False

    # Check if extracted folder already exists in GCS
    gcs_extracted_prefix = f"processed/adobe_extracted/{pdf_name}/"
    blobs = list(bucket.list_blobs(prefix=gcs_extracted_prefix))
    if blobs:  # Skip if extracted files already exist
        print(f"Skipping {pdf_name}: Extracted files already exist in GCS.")
        return True

    # Retry mechanism
    for attempt in range(1, max_retries + 1):
        try:
            print(f"Processing PDF: {pdf_name} (Attempt {attempt}/{max_retries})...")

            # Step 1: Download PDF to a temp file
            with NamedTemporaryFile(delete=False, suffix=".pdf") as temp_file:
                temp_file_path = temp_file.name
                blob.download_to_filename(temp_file_path)

            # Step 2: Process PDF with adobeLoader
            adobeLoader(
                temp_file_path,
                output_zip_path,
                client_id=client_id,
                client_secret=client_secret,
            )

            # Step 3: Upload the processed ZIP file to GCS
            gcs_destination = f"processed/adobe_result/{pdf_name}/sdk.zip"
            public_url = upload_file(output_zip_path, gcs_destination)
            print(f"Uploaded to GCS: {public_url}")

            # Step 4: Unzip and upload extracted files to GCS
            print(f"Extracting ZIP for {pdf_name} and uploading files to GCS...")
            with open(output_zip_path, "rb") as zip_file_stream:
                with ZipFile(zip_file_stream) as zip_file:
                    for file_name in zip_file.namelist():
                        file_data = zip_file.read(file_name)  # Read extracted content
                        extracted_blob_name = (
                            f"processed/adobe_extracted/{pdf_name}/{file_name}"
                        )

                        # Upload extracted file to GCS
                        extracted_blob = bucket.blob(extracted_blob_name)
                        extracted_blob.upload_from_string(file_data)
                        print(f"Uploaded extracted file to GCS: {extracted_blob_name}")

            success = True
            break  # Exit loop on success

        except Exception as e:
            print(f"Error processing PDF {pdf_name} (Attempt {attempt}): {e}")
            if attempt < max_retries:
                print(f"Retrying in {retry_delay} seconds...")
                time.sleep(retry_delay)
            else:
                print(f"Failed to process PDF {pdf_name} after {max_retries} attempts.")

        finally:
            # Cleanup temporary file
            if temp_file_path and os.path.exists(temp_file_path):
                os.remove(temp_file_path)

    return success

# %%
load_dotenv(override=True)
# Out:
# True

# %%
def main():
    load_dotenv(override=True)

    # Get configuration
    bucket_name = "wedding-venues-001"
    client_id = os.getenv("ADOBE_CLIENT_ID")
    client_secret = os.getenv("ADOBE_CLIENT_SECRET")
    if not all([bucket_name, client_id, client_secret]):
        raise ValueError("Missing required environment variables")
    print(f"client id is {client_id}")

    # List all files
    print("Listing files in bucket...")
    files = list_files(bucket_name=bucket_name, filter="venues/")
    pdf_files = [f for f in files if f.lower().endswith(".pdf")]
    pdf_files = pdf_files[195:]  # Process first 100 files
    print(f"Found {len(pdf_files)} PDF files")

    # GCS folder for processed results
    output_folder = "processed/adobe_result"

    # Process each PDF
    results = {"successful": 0, "failed": 0, "failed_files": []}

    for pdf_file in pdf_files:
        success = process_pdf_from_cloud_with_temp_file(
            bucket_name=bucket_name,
            blob_name=pdf_file,
            output_folder=output_folder,
            client_id=client_id,
            client_secret=client_secret,
            max_retries=3,
            retry_delay=5,
        )

        if success:
            results["successful"] += 1
        else:
            results["failed"] += 1
            results["failed_files"].append(pdf_file)

    # Print summary
    print("\nProcessing Summary:")
    print(f"Successfully processed: {results['successful']}")
    print(f"Failed: {results['failed']}")
    if results["failed_files"]:
        print("\nFailed files:")
        for file in results["failed_files"]:
            print(f"- {file}")

# %%
bucket_name = "wedding-venues-001"
if __name__ == "__main__":
    main()
# Out:
# client id is cd7c3784d3954b52bfd060cdf1ec04f0
# Listing files in bucket...
# Found 85 PDF files
# Processing PDF: San Ysidro Ranch (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/San%20Ysidro%20Ranch/sdk.zip
# Extracting ZIP for San Ysidro Ranch and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/San Ysidro Ranch/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/San Ysidro Ranch/figures/fileoutpart9.png
# Uploaded extracted file to GCS: processed/adobe_extracted/San Ysidro Ranch/figures/fileoutpart4.png
# Uploaded extracted file to GCS: processed/adobe_extracted/San Ysidro Ranch/figures/fileoutpart3.png
# Uploaded extracted file to GCS: processed/adobe_extracted/San Ysidro Ranch/figures/fileoutpart6.png
# Uploaded extracted file to GCS: processed/adobe_extracted/San Ysidro Ranch/figures/fileoutpart8.png
# Uploaded extracted file to GCS: processed/adobe_extracted/San Ysidro Ranch/figures/fileoutpart5.png
# Uploaded extracted file to GCS: processed/adobe_extracted/San Ysidro Ranch/figures/fileoutpart11.png
# Uploaded extracted file to GCS: processed/adobe_extracted/San Ysidro Ranch/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/San Ysidro Ranch/figures/fileoutpart10.png
# Uploaded extracted file to GCS: processed/adobe_extracted/San Ysidro Ranch/figures/fileoutpart7.png
# Uploaded extracted file to GCS: processed/adobe_extracted/San Ysidro Ranch/figures/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/San Ysidro Ranch/figures/fileoutpart1.png
# Processing PDF: Santa Barbara Botanic Garden (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Santa%20Barbara%20Botanic%20Garden/sdk.zip
# Extracting ZIP for Santa Barbara Botanic Garden and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/figures/fileoutpart19.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/figures/fileoutpart25.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/figures/fileoutpart8.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/figures/fileoutpart24.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/figures/fileoutpart20.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/figures/fileoutpart22.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/figures/fileoutpart7.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/figures/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/figures/fileoutpart23.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/figures/fileoutpart21.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/figures/fileoutpart1.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/tables/fileoutpart18.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/tables/fileoutpart4.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/tables/fileoutpart16.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/tables/fileoutpart12.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/tables/fileoutpart6.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/tables/fileoutpart15.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/tables/fileoutpart3.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/tables/fileoutpart5.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/tables/fileoutpart9.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/tables/fileoutpart17.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/tables/fileoutpart10.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/tables/fileoutpart13.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/tables/fileoutpart14.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Botanic Garden/tables/fileoutpart11.xlsx
# Processing PDF: Santa Barbara Historical Museum (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Santa%20Barbara%20Historical%20Museum/sdk.zip
# Extracting ZIP for Santa Barbara Historical Museum and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Barbara Historical Museum/structuredData.json
# Processing PDF: Santa Maria Country Club (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Santa%20Maria%20Country%20Club/sdk.zip
# Extracting ZIP for Santa Maria Country Club and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart18.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart4.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart19.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart42.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart25.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart16.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart12.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart3.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart30.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart58.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart32.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart28.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart6.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart31.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart13.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart34.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart43.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart24.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart5.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart35.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart41.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart20.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart22.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart17.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart33.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart26.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart7.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart23.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart27.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart29.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart21.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart36.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/figures/fileoutpart1.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart9.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart56.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart53.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart37.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart54.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart15.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart55.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart51.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart52.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart11.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart48.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart50.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart10.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart39.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart8.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart40.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart49.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart57.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart46.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart47.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart38.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart14.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart44.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Maria Country Club/tables/fileoutpart45.png
# Processing PDF: Santa Monica Proper (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Santa%20Monica%20Proper/sdk.zip
# Extracting ZIP for Santa Monica Proper and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Monica Proper/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Monica Proper/figures/fileoutpart4.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Monica Proper/figures/fileoutpart3.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Monica Proper/figures/fileoutpart6.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Monica Proper/figures/fileoutpart5.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Monica Proper/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Monica Proper/figures/fileoutpart7.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Monica Proper/figures/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Santa Monica Proper/figures/fileoutpart1.png
# Processing PDF: Scripps Seaside Forum (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Scripps%20Seaside%20Forum/sdk.zip
# Extracting ZIP for Scripps Seaside Forum and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Scripps Seaside Forum/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/Scripps Seaside Forum/figures/fileoutpart6.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Scripps Seaside Forum/figures/fileoutpart5.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Scripps Seaside Forum/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Scripps Seaside Forum/figures/fileoutpart7.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Scripps Seaside Forum/figures/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Scripps Seaside Forum/figures/fileoutpart1.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Scripps Seaside Forum/tables/fileoutpart4.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Scripps Seaside Forum/tables/fileoutpart3.xlsx
# Processing PDF: Serendipity Garden (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Serendipity%20Garden/sdk.zip
# Extracting ZIP for Serendipity Garden and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Serendipity Garden/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/Serendipity Garden/figures/fileoutpart4.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Serendipity Garden/figures/fileoutpart3.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Serendipity Garden/figures/fileoutpart6.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Serendipity Garden/figures/fileoutpart8.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Serendipity Garden/figures/fileoutpart5.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Serendipity Garden/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Serendipity Garden/figures/fileoutpart7.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Serendipity Garden/figures/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Serendipity Garden/figures/fileoutpart1.png
# Processing PDF: Seventh Place (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Seventh%20Place/sdk.zip
# Extracting ZIP for Seventh Place and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart9.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart18.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart4.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart19.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart25.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart16.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart12.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart3.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart6.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart15.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart13.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart8.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart24.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart5.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart11.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart20.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart22.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart10.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart17.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart14.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart26.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart7.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart23.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart27.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart21.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Seventh Place/figures/fileoutpart1.png
# Processing PDF: Sherman Library & Gardens (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Sherman%20Library%20%26%20Gardens/sdk.zip
# Extracting ZIP for Sherman Library & Gardens and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherman Library & Gardens/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherman Library & Gardens/figures/fileoutpart4.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherman Library & Gardens/figures/fileoutpart3.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherman Library & Gardens/figures/fileoutpart5.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherman Library & Gardens/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherman Library & Gardens/figures/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherman Library & Gardens/figures/fileoutpart1.png
# Processing PDF: Sherwood Country Club (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Sherwood%20Country%20Club/sdk.zip
# Extracting ZIP for Sherwood Country Club and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart9.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart18.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart39.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart42.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart16.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart12.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart3.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart15.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart13.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart8.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart34.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart43.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart24.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart35.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart11.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart41.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart22.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart10.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart17.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart40.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart37.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart14.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart38.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart23.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart27.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart21.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart36.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/figures/fileoutpart1.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/tables/fileoutpart4.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/tables/fileoutpart28.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/tables/fileoutpart19.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/tables/fileoutpart32.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/tables/fileoutpart25.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/tables/fileoutpart31.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/tables/fileoutpart6.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/tables/fileoutpart5.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/tables/fileoutpart20.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/tables/fileoutpart33.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/tables/fileoutpart26.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/tables/fileoutpart30.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/tables/fileoutpart7.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sherwood Country Club/tables/fileoutpart29.png
# Processing PDF: Sierra La Verne Wedgewood (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Sierra%20La%20Verne%20Wedgewood/sdk.zip
# Extracting ZIP for Sierra La Verne Wedgewood and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart9.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart18.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart44.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart19.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart42.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart16.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart12.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart15.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart13.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart8.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart43.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart24.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart11.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart41.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart20.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart22.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart10.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart17.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart14.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart46.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart7.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart23.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart21.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/figures/fileoutpart45.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart4.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart37.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart30.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart32.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart28.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart25.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart6.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart34.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart27.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart33.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart3.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart31.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart5.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart39.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart29.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart40.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart35.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart26.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart38.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart36.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sierra La Verne Wedgewood/tables/fileoutpart1.xlsx
# Processing PDF: Skirball Cultural Center (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Skirball%20Cultural%20Center/sdk.zip
# Extracting ZIP for Skirball Cultural Center and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Skirball Cultural Center/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/Skirball Cultural Center/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Skirball Cultural Center/tables/fileoutpart4.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Skirball Cultural Center/tables/fileoutpart6.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Skirball Cultural Center/tables/fileoutpart8.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Skirball Cultural Center/tables/fileoutpart3.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Skirball Cultural Center/tables/fileoutpart5.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Skirball Cultural Center/tables/fileoutpart7.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Skirball Cultural Center/tables/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Skirball Cultural Center/tables/fileoutpart1.xlsx
# Processing PDF: Skybox San Diego (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Skybox%20San%20Diego/sdk.zip
# Extracting ZIP for Skybox San Diego and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Skybox San Diego/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/Skybox San Diego/figures/fileoutpart4.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Skybox San Diego/figures/fileoutpart3.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Skybox San Diego/figures/fileoutpart6.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Skybox San Diego/figures/fileoutpart8.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Skybox San Diego/figures/fileoutpart5.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Skybox San Diego/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Skybox San Diego/figures/fileoutpart7.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Skybox San Diego/figures/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Skybox San Diego/figures/fileoutpart1.png
# Processing PDF: South Bay Event Center (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/South%20Bay%20Event%20Center/sdk.zip
# Extracting ZIP for South Bay Event Center and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/South Bay Event Center/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/South Bay Event Center/tables/fileoutpart0.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/South Bay Event Center/tables/fileoutpart1.png
# Processing PDF: South Coast Winery Resort & Spa (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/South%20Coast%20Winery%20Resort%20%26%20Spa/sdk.zip
# Extracting ZIP for South Coast Winery Resort & Spa and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart9.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart18.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart4.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart19.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart16.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart12.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart3.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart6.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart15.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart13.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart8.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart5.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart11.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart20.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart22.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart10.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart17.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart14.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart7.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart21.png
# Uploaded extracted file to GCS: processed/adobe_extracted/South Coast Winery Resort & Spa/figures/fileoutpart1.png
# Processing PDF: Springville Ranch (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Springville%20Ranch/sdk.zip
# Extracting ZIP for Springville Ranch and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Springville Ranch/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/Springville Ranch/figures/fileoutpart0.png
# Processing PDF: Sterling Hills Wedgewood (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Sterling%20Hills%20Wedgewood/sdk.zip
# Extracting ZIP for Sterling Hills Wedgewood and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart9.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart18.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart44.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart19.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart42.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart16.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart12.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart15.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart13.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart8.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart43.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart24.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart11.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart41.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart20.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart22.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart10.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart17.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart14.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart46.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart7.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart47.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart23.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart21.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/figures/fileoutpart45.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart4.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart37.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart30.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart32.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart28.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart25.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart6.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart34.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart27.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart33.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart3.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart31.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart5.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart39.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart29.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart40.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart35.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart26.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart38.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart36.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Sterling Hills Wedgewood/tables/fileoutpart1.xlsx
# Processing PDF: Storrier Japanese Garden (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Storrier%20Japanese%20Garden/sdk.zip
# Extracting ZIP for Storrier Japanese Garden and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Storrier Japanese Garden/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/Storrier Japanese Garden/figures/fileoutpart4.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Storrier Japanese Garden/figures/fileoutpart3.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Storrier Japanese Garden/figures/fileoutpart5.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Storrier Japanese Garden/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Storrier Japanese Garden/figures/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Storrier Japanese Garden/figures/fileoutpart1.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Storrier Japanese Garden/tables/fileoutpart9.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Storrier Japanese Garden/tables/fileoutpart12.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Storrier Japanese Garden/tables/fileoutpart15.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Storrier Japanese Garden/tables/fileoutpart13.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Storrier Japanese Garden/tables/fileoutpart6.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Storrier Japanese Garden/tables/fileoutpart11.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Storrier Japanese Garden/tables/fileoutpart10.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Storrier Japanese Garden/tables/fileoutpart8.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Storrier Japanese Garden/tables/fileoutpart7.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Storrier Japanese Garden/tables/fileoutpart14.xlsx
# Processing PDF: Surf and Sand Laguna Beach (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Surf%20and%20Sand%20Laguna%20Beach/sdk.zip
# Extracting ZIP for Surf and Sand Laguna Beach and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Surf and Sand Laguna Beach/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/Surf and Sand Laguna Beach/figures/fileoutpart9.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Surf and Sand Laguna Beach/figures/fileoutpart4.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Surf and Sand Laguna Beach/figures/fileoutpart12.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Surf and Sand Laguna Beach/figures/fileoutpart3.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Surf and Sand Laguna Beach/figures/fileoutpart6.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Surf and Sand Laguna Beach/figures/fileoutpart13.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Surf and Sand Laguna Beach/figures/fileoutpart8.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Surf and Sand Laguna Beach/figures/fileoutpart5.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Surf and Sand Laguna Beach/figures/fileoutpart11.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Surf and Sand Laguna Beach/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Surf and Sand Laguna Beach/figures/fileoutpart10.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Surf and Sand Laguna Beach/figures/fileoutpart14.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Surf and Sand Laguna Beach/figures/fileoutpart7.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Surf and Sand Laguna Beach/figures/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Surf and Sand Laguna Beach/figures/fileoutpart1.png
# Processing PDF: Swallow Creek Ranch (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Swallow%20Creek%20Ranch/sdk.zip
# Extracting ZIP for Swallow Creek Ranch and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Swallow Creek Ranch/structuredData.json
# Processing PDF: Swanner House_ (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Swanner%20House_/sdk.zip
# Extracting ZIP for Swanner House_ and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Swanner House_/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/Swanner House_/figures/fileoutpart9.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Swanner House_/figures/fileoutpart18.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Swanner House_/figures/fileoutpart39.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Swanner House_/figures/fileoutpart4.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Swanner House_/figures/fileoutpart44.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Swanner House_/figures/fileoutpart19.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Swanner House_/figures/fileoutpart42.png
# ...
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart68.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart55.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart13.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart8.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart62.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart34.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart43.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart77.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart78.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart48.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart67.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart73.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart51.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart24.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart5.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart64.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart35.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart11.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart41.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart75.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart74.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart50.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart20.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart60.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart22.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart59.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart72.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart65.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart10.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart17.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart40.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart49.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart81.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart37.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart57.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart33.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart52.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart14.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart61.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart26.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart46.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart7.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart47.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart38.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart23.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart27.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart29.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart21.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart36.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart71.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart1.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart45.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Westridge Golf Club/figures/fileoutpart54.png
# Processing PDF: Willow Woods Park (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Willow%20Woods%20Park/sdk.zip
# Extracting ZIP for Willow Woods Park and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Willow Woods Park/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/Willow Woods Park/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Willow Woods Park/figures/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Willow Woods Park/figures/fileoutpart1.png
# Processing PDF: Wiltern (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Wiltern/sdk.zip
# Extracting ZIP for Wiltern and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/figures/fileoutpart9.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/figures/fileoutpart30.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/figures/fileoutpart32.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/figures/fileoutpart28.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/figures/fileoutpart6.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/figures/fileoutpart31.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/figures/fileoutpart34.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/figures/fileoutpart37.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/figures/fileoutpart33.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/figures/fileoutpart26.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/figures/fileoutpart38.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/figures/fileoutpart27.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/figures/fileoutpart29.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/figures/fileoutpart1.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart18.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart4.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart12.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart25.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart3.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart19.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart15.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart13.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart8.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart23.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart24.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart5.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart11.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart20.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart22.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart10.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart16.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart17.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart35.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart7.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart21.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart14.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart36.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Wiltern/tables/fileoutpart2.xlsx
# Processing PDF: Yamashiro Hollywood (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/Yamashiro%20Hollywood/sdk.zip
# Extracting ZIP for Yamashiro Hollywood and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart9.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart18.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart4.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart19.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart16.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart12.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart3.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart6.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart15.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart13.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart8.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart24.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart5.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart11.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart20.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart22.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart10.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart17.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart14.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart7.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart23.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart21.png
# Uploaded extracted file to GCS: processed/adobe_extracted/Yamashiro Hollywood/figures/fileoutpart1.png
# Processing PDF: a.o.c. Brentwood (Attempt 1/3)...
# Uploaded to GCS: https://storage.googleapis.com/wedding-venues-001/processed/adobe_result/a.o.c.%20Brentwood/sdk.zip
# Extracting ZIP for a.o.c. Brentwood and uploading files to GCS...
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/structuredData.json
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/figures/fileoutpart18.png
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/figures/fileoutpart4.png
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/figures/fileoutpart19.png
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/figures/fileoutpart16.png
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/figures/fileoutpart3.png
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/figures/fileoutpart15.png
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/figures/fileoutpart5.png
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/figures/fileoutpart20.png
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/figures/fileoutpart22.png
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/figures/fileoutpart0.png
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/figures/fileoutpart17.png
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/figures/fileoutpart14.png
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/figures/fileoutpart2.png
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/figures/fileoutpart21.png
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/figures/fileoutpart1.png
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/tables/fileoutpart9.png
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/tables/fileoutpart12.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/tables/fileoutpart13.png
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/tables/fileoutpart6.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/tables/fileoutpart11.png
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/tables/fileoutpart10.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/tables/fileoutpart8.xlsx
# Uploaded extracted file to GCS: processed/adobe_extracted/a.o.c. Brentwood/tables/fileoutpart7.png
#
# Processing Summary:
# Successfully processed: 83
# Failed: 2
#
# Failed files:
# - venues/The Grand Long Beach/The Grand Long Beach.pdf
# - venues/Vibiana/Vibiana.pdf

# %%
import re

from google.cloud import storage


def list_main_folders(bucket_name, filter=None):
    if filter is not None:
        filter = re.compile(filter, re.IGNORECASE)

    client = storage.Client()
    bucket = client.bucket(bucket_name)
    blobs = bucket.list_blobs()

    # Collect only primary folders (ignoring deeper paths like "figures" or "tables")
    main_folders = set()
    for blob in blobs:
        if "/" in blob.name:  # Check for folder-like structure
            folder_path = "/".join(blob.name.split("/")[:-1])  # Exclude the file itself
            if filter is None or filter.search(folder_path):
                # Only include top-level folders (filter out deeper paths)
                if not any(
                    folder_path.endswith(extra) for extra in ["/figures", "/tables"]
                ):
                    main_folders.add(folder_path)

    return sorted(main_folders)  # Return sorted folder names


# Example usage
bucket_name = "wedding-venues-001"
folders = list_main_folders(bucket_name=bucket_name, filter="processed/adobe_extracted")
len(folders)
# Out:
# 271
